# %% [markdown]
# <a href="https://colab.research.google.com/github/Drhonghanchen/colab_misc/blob/main/seg_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
import torchvision.datasets as datasets
from PIL import Image

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/VOC2007'

# %%
voc_val =datasets.VOCSegmentation(path,year='2012',image_set='val',download=False)
print(voc_val)
# Out:
# Dataset VOCSegmentation
#     Number of datapoints: 1449
#     Root location: /content/drive/MyDrive/VOC2007

# %%
(image,target) = voc_val[7]
print(type(image),image.size)
print(type(target),target.size)
image.show()
display(image)
target.show()
display(target)
# Out:
# <class 'PIL.Image.Image'> (500, 375)
# <class 'PIL.PngImagePlugin.PngImageFile'> (500, 375)
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7FCA7893CB50>
# <PIL.PngImagePlugin.PngImageFile image mode=P size=500x375 at 0x7FCA7893C910>
